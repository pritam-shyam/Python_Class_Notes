# %% [markdown]
# # =============================================================

# %% [markdown]
# # Notebooks consist of Cells
#
# Jupyter notebooks consist of cells. Cells are one of three basic types. The most popular are code and markdown. We will enter and execture our Python code in Code cells and use Markdown cells to enter documentation using the same Markdown language we've been using on GitHub. The third type of cell is NBConvert - these are cells that are not interpreted/processed by Jupyter (we will not be using these types of cells).
#
# The cell (this cell) that you are viewing is a markdown cell.
#
# To change cell type, go to Cell->Cell Type Menu
#
# NOTE: Hitting escape in a cell will turn the call border blue. When in this mode, you can enter commands. For instance, you can change a cell to Markdown by simply entering M.

# %% [markdown]
# # Basic navigation
#
#
# Cells can be in either command mode (cell is in focus with blue border) or edit mode (green border). Clicking within the content of a cell will put it into edit mode. Once in edit mode, you can enter content within the cell. Hitting escape while editing a cell will result in switching to control mode. Also, you can also select a cell by clicking on the area just left of the content, and this will highlight the cell in control mode (blue border).
#
# SHIFT-ENTER will result in executing a cell (or rendering it if it's markdown)
# ALT-ENTER will result in both executing a cell, and creating (inserting) a new cell below the cell in which you have in focus.
#
# To delete any cell, ensure that this cell is highlighted in blue, and hit the letter d then d.

# %% [markdown]
# # =============================================================

# %% [markdown]
# # Markdown Cells

# %% [markdown]
# Markdown cells are rendered cells. We can use markdown (md files like we have been using already), HTML, or Latex
#
# ### Header three (markdown)
#
# <strong>bolded</strong> HTML
#
# $LATEX$
#
# NOTE: Try clicking on this cell to edit, and you will see the code behind what we see rendered here.

# %% [markdown]
# # Markdown (MD)

# %% [markdown]
# Most of our markdown will be MD, with possibly a bit of HTML on occassion. Here is some example MD "code" to demonstrate the rendering features of Jupyter.
#
# ### All the header types are interpreted:
#
# ```
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
# ```
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6
#
#
# ### Emphasis
#
# #### Raw Markdown of various emphasis options:
#
# ```
# Emphasis, aka italics, with *asterisks* or _underscores_.
#
# Strong emphasis, aka bold, with **asterisks** or __underscores__.
#
# Combined emphasis with **asterisks and _underscores_**.
#
# Strikethrough uses two tildes. ~~Scratch this.~~
#
# ```
#
# #### Rendered Markdwon:
#
# Emphasis, aka italics, with *asterisks* or _underscores_.
#
# Strong emphasis, aka bold, with **asterisks** or __underscores__.
#
# Combined emphasis with **asterisks and _underscores_**.
#
# Strikethrough uses two tildes. ~~Scratch this.~~
#
# ### Lists
#
# #### Raw Markdown of Lists:
# ```
# 1. First ordered list item
# 2. Another item
#   * Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
#   1. Ordered sub-list
# 4. And another item.
# ```
# #### Rendered Markdown of Lists:
#
# 1. First ordered list item
# 2. Another item
#    * Unordered sub-list.
# 1. Actual numbers don't matter, just that it's a number
#    1. Ordered sub-list
# 4. And another item.
#
# ### Images
#
# ![alt text](images/iowastate_MIS407.png)
#
# #### ...and, we get Python Code highlighting in markdown
#
# ```python
# print("Hello World")
# ```
#
# ## For further reading
#
# See the markdown "cheatsheet" https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet

# %% [markdown]
# # =============================================================

# %% [markdown]
# # Code Cells

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # =============================================================

# %% [markdown]
# # Code Cell Demos
#
# Let's run a few demos to test our installation.
#
# First, note that this cell is a "markdown" cell. Each cell can be specified as a type. The default is to assume it is a "code" cell. You can change this type setting by selecting the cell you want to change and going into the cell->Cell Type menu.
#
# Now, let's try a few demos....

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
def fun(str):
    print(str)
    
fun("Hello World!")
# Out:
# Hello World!

# %%
def fun(str, reps):
    for i in range(reps):
        print(str)

fun("Hello World", 10)
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %% [markdown]
# Now, each cell can be run independently, but they are all within the same namespace. Therefore, if I do the following...

# %%
somevar = "some value"

# %% [markdown]
# ...then, I can access somevar from another cell.

# %%
print(somevar)
# Out:
# some value

# %% [markdown]
# NOTE: that the somevar variable code must be "run" before we attempt the run the print code in the other cell. As mentioned previously, you execute the code within a cell by pressing enter with the cell in focus.

# %% [markdown]
# ## Plotting with Bokeh

# %% [markdown]
# ### Scatter Plots

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

output_notebook()

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d9fb903f-e999-4c2f-b7ed-93b77cdbb0ed">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="77ff68f7-519e-411a-b50f-b5c5bab334a7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77ff68f7-519e-411a-b50f-b5c5bab334a7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77ff68f7-519e-411a-b50f-b5c5bab334a7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d2d047a1-3e97-45d4-847b-44bfbd0a157d":{"roots":{"references":[{"attributes":{"plot":{"id":"024725f4-ef8a-46b7-8a55-1d34ca8833d0","subtype":"Figure","type":"Plot"}},"id":"ea2ab4d7-0d61-43e8-8014-0e6df03f14ca","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"9db40d97-6468-4c74-bf42-c28dedd027da","type":"Circle"},{"attributes":{},"id":"da07e3fb-cf47-4bdc-84fb-b3475873ea05","type":"BasicTicker"},{"attributes":{"callback":null},"id":"153a7c37-c811-4da8-84f6-ffee54794a1b","type":"DataRange1d"},{"attributes":{"plot":null,"text":null},"id":"863921dc-aed2-48ae-99e5-1407e6477ce3","type":"Title"},{"attributes":{"formatter":{"id":"4a5e3ee0-d6f8-4489-8d09-3518a9d22276","type":"BasicTickFormatter"},"plot":{"id":"024725f4-ef8a-46b7-8a55-1d34ca8833d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"da07e3fb-cf47-4bdc-84fb-b3475873ea05","type":"BasicTicker"}},"id":"4011e6bf-050a-43e0-b05c-1da7b8f77401","type":"LinearAxis"},{"attributes":{},"id":"8287986c-9efd-41c9-bbe7-fb4b2d4ad06f","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"2ef4c379-3dc2-4dde-940f-ffeb64408b53","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"2bc96129-f48c-48f3-9c54-e118f7bf6a10","type":"BasicTickFormatter"},"plot":{"id":"024725f4-ef8a-46b7-8a55-1d34ca8833d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b8f10788-8a3f-4ff8-a9d9-5abf6295cd69","type":"BasicTicker"}},"id":"436b5186-1775-4328-bb85-90a5d0edafff","type":"LinearAxis"},{"attributes":{"overlay":{"id":"0148614e-d464-41d0-b07d-2eb0bc6efcee","type":"BoxAnnotation"},"plot":{"id":"024725f4-ef8a-46b7-8a55-1d34ca8833d0","subtype":"Figure","type":"Plot"}},"id":"a263bca7-965f-43e7-a709-a9c3f0a4843e","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"024725f4-ef8a-46b7-8a55-1d34ca8833d0","subtype":"Figure","type":"Plot"}},"id":"7d3c7312-e35c-45ac-aef8-cdc22c90bd56","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"
","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a873137b-9a0d-4df3-9f94-71eed04221d0","type":"ColumnDataSource"},"glyph":{"id":"fd96ee62-c709-4b4b-9a34-f955170a6fd5","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"6e1002bc-8164-417f-96e6-c59ea4f4767c","type":"Square"},"selection_glyph":null},"id":"24084450-716b-41cc-b849-ef88009e0efd","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"131d6c25-a77b-4330-a479-bbd1f7e3644b","subtype":"Figure","type":"Plot"},"ticker":{"id":"160a17e4-43d6-49ea-9065-ad8524a12224","type":"BasicTicker"}},"id":"6bbf59f4-0cb6-4ebe-8a97-4fbc8bf9c282","type":"Grid"},{"attributes":{},"id":"1b1b51f8-87ad-4888-aec6-31f1c8f13e3c","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9e90c169-c6dc-43b7-8359-f45973901e5a","type":"PanTool"},{"id":"f2ed5551-6249-443e-adc4-08c4672c3348","type":"WheelZoomTool"},{"id":"b751b379-a595-4dec-b1e4-7872fe00517e","type":"BoxZoomTool"},{"id":"67cec788-22b1-4b26-afff-19a449902c15","type":"SaveTool"},{"id":"edaafe79-9735-43a1-99b6-579ad36192b9","type":"ResetTool"},{"id":"cf404649-882b-4f9f-a19b-f3bc7ea47843","type":"HelpTool"}]},"id":"52be9032-1d88-4de2-b7ef-ee49810dbf1f","type":"Toolbar"},{"attributes":{"plot":{"id":"131d6c25-a77b-4330-a479-bbd1f7e3644b","subtype":"Figure","type":"Plot"}},"id":"67cec788-22b1-4b26-afff-19a449902c15","type":"SaveTool"},{"attributes":{},"id":"368cbcc2-9031-4bd0-abf7-683a3d9be795","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"368cbcc2-9031-4bd0-abf7-683a3d9be795","type":"BasicTickFormatter"},"plot":{"id":"131d6c25-a77b-4330-a479-bbd1f7e3644b","subtype":"Figure","type":"Plot"},"ticker":{"id":"160a17e4-43d6-49ea-9065-ad8524a12224","type":"BasicTicker"}},"id":"932f6d25-1ed1-448d-a949-a11162c0cb3d","type":"LinearAxis"},{"attributes":{"below":[{"id":"932f6d25-1ed1-448d-a949-a11162c0cb3d","type":"LinearAxis"}],"left":[{"id":"ed222fa3-4db1-40f3-8801-73276f4cc813","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"932f6d25-1ed1-448d-a949-a11162 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[21]</strong>&gt;</code></p>

# %% [markdown]
# #### There are lots of marker types available in Bokeh:
# ```
# asterisk()
# circle()
# circle_cross()
# circle_x()
# cross()
# diamond()
# diamond_cross()
# inverted_triangle()
# square()
# square_cross()
# square_x()
# triangle()
# ```

# %% [markdown]
# ### Line Plots

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

output_notebook()

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
t=show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8784ae8e-8862-44f5-958d-c788e57d60fb">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="4d72e367-6416-49bf-82ad-d558cf702228"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d72e367-6416-49bf-82ad-d558cf702228");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d72e367-6416-49bf-82ad-d558cf702228' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a91ae974-709f-4148-a3ca-59eaecba9938":{"roots":{"references":[{"attributes":{"plot":{"id":"35f65d78-daa3-4c01-81ca-cf0e1872f4b4","subtype":"Figure","type":"Plot"}},"id":"d5981bf3-31c2-46e6-97fc-ec97f7bb5a84","type":"HelpTool"},{"attributes":{},"id":"9d6ca357-e81b-4224-bd2e-6061990ff42c","type":"BasicTicker"},{"attributes":{},"id":"ccd3c619-aabd-44a3-97e6-e0a0a5c428e0","type":"ToolEvents"},{"attributes":{"overlay":{"id":"02833423-2d58-4847-ab15-6accdd94f925","type":"BoxAnnotation"},"plot":{"id":"35f65d78-daa3-4c01-81ca-cf0e1872f4b4","subtype":"Figure","type":"Plot"}},"id":"7da0f545-a4c7-46c1-a3ab-e8f87838c8a8","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":
4","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c6a3be1-bf0d-4f27-bfab-f3c40dcfe1c2","type":"BasicTicker"}},"id":"303e0113-f08c-484e-aea2-895d6ab3324c","type":"LinearAxis"},{"attributes":{"callback":null},"id":"c1f5a466-f3ac-442e-835d-34bb3e34e671","type":"DataRange1d"},{"attributes":{"plot":{"id":"35f65d78-daa3-4c01-81ca-cf0e1872f4b4","subtype":"Figure","type":"Plot"}},"id":"b52d97ce-465f-47f6-b412-b5600c66263e","type":"ResetTool"},{"attributes":{"axis_label":"x","formatter":{"id":"098206ed-935a-478d-8cec-f9869ff9ce3c","type":"BasicTickFormatter"},"plot":{"id ...

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook

output_notebook()

p = figure(plot_width=400, plot_height=400)

p.multi_line([[1, 3, 2], [3, 4, 6, 6]], [[2, 1, 4], [4, 7, 8, 5]],
             color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2410800f-2389-4794-916d-8e90a94fb525">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="04cd5273-6130-4f6a-9310-ce5b550f880d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04cd5273-6130-4f6a-9310-ce5b550f880d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04cd5273-6130-4f6a-9310-ce5b550f880d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b6c6a021-f113-466a-90f4-5fd7e326d733":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["ys","xs","line_alpha","line_color"],"data":{"line_alpha":[0.8,0.3],"line_color":["firebrick","navy"],"xs":[[1,3,2],[3,4,6,6]],"ys":[[2,1,4],[4,7,8,5]]}},"id":"211587d4-5ce6-4fdf-b513-a0fcf4c9f25c","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"0270ecd1-98f7-4055-a531-ba10c00c18bd","type":"BasicTickFormatter"},"plot":{"id":"55ac45e7-1d14-48e8-9e6f-876c3b075436","subtype":"Figure","type":"Plot"},"ticker":{"id":"35bb964d-b482-4e96-8584-fc940dd038d4","type":"BasicTicker"}},"id":"4f3d9995-240d-43bd-b6be-a66b22f3a531","type":"LinearAxis"},{"attributes":{"overlay":{"id":"eb00f970-d83c-4f03-aac7-2134299c8e8b","type":"BoxAnnotation"},"plot":{"id":"55ac45e7-1d14-48e8-9e6f-876c3b075436","subtype":"Figure","type":"Plot"}},"id":"dcd8e8c6-fac4-427c-9fe4-47091c5a17eb","type":"BoxZoomTool"},{"attributes":{},"id":"36c95141-97f0-4e8d-b9f9-e99f0061af39","type":"ToolEvents"},{"attributes":{},"id":"0270ecd1-98f7-4055-a531-ba10c00c18bd","type":"BasicTickFormatter"},{"attributes":{},"id":"35bb964d-b482-4e96-8584-fc940dd038d4","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"82de1c67-1eec-42a2-a706-3638a612ec1f","type":"PanTool"},{"id":"980c7321-46ab-4a94-a755-fb0ab7c4cc2f","type":"WheelZoomTool"},{"id":"dcd8e8c6-fac4-427c-9fe4-47091c5a17eb","type":"BoxZoomTool"},{"id":"70c0405a-fc18-4494-a8b7-7ef3bdca1dd7","type":"SaveTool"},{"id":"5bc2452d-f6c5-4000-8975-3f2317a59c6b","type":"ResetTool"},{"id":"058fc0ea-2361-469b-9904-dbb3ac620dc0","type":"HelpTool"}]},"id":"f70e4290-3199-4bdf-a51a-63278f28ba6c","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"55ac45e7-1d14-48e8-9e6f-876c3b075436","subtype":"Figure","type":"Plot"},"ticker":{"id":"24056263-ed2d-4f96-bc77-ea41ba2175e0","type":"BasicTicker"}},"id":"2cf11ac9-02c8-438e-9b7e-99a0d1ff941e","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"eb00f970-d83c-4f03-aac7-2134299c8e8b","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"e0b046e4-2ffa-446e-a8c8-fe706e56d345","type":"MultiLine"},{"attributes":{"callback":null},"id":"256bb407-85f8-4231-97f7-f679d7fc9cc0","type":"DataRange1d"},{"attributes":{"below":[{"id":"4f3d9995-240d-43bd-b6be-a66b22f3a531","type":"LinearAxis"}],"left":[{"id":"7f309729-144a-465e-949c-61e03ea55972","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"4f3d9995-240d-43bd-b6be-a66b22f3a531","type":"LinearAxis"},{"id":"070a6b2f-cc46-4ecf-b928-10fed17405ef","type":"Grid"},{"id":"7f309729-144a-465e-949c-61e03ea55972","type":"LinearAxis"},{"id":"2cf11ac9-02c8-438e-9b7e-99a0d1ff941e","type":"Grid"},{"id":"eb00f970-d83c-4f03-aac7-2134299c8e8b","type":"BoxAnnotation"},{"id":"5e6be545-03bc-42d6-bbb0-44b883972698","type":"GlyphRenderer"}],"title":{"id":"e4507d78-5a40-4633-8f9b-bc92d68354af","type":"Title"},"tool_events":{"id":"36c95141-97f0-4e8d-b9f9-e99f0061af39","type":"ToolEvents"},"toolbar":{"id":"f70e4290-3199-4bdf-a51a-63278f28ba6c","type":"Toolbar"},"x_range":{"id":"256bb407-85f8-4231-97f7-f679d7fc9cc0","type":"DataRange1d"},"y_range":{"id":"93402fea-c3e6-4a7e-8c5e-60373699db55","type":"DataRange1d"}},"id":"55ac45e7-1d14-48e8-9e6f-876c3b075436","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c392ef13-7c58-494e-8884-d05d51d4db77","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"55ac45e7-1d14-48e8-9e6f-876c3b075436","subtype":"Figure","type":"Plot"}},"id":"82de1c67-1eec-42a2-a706-3638a612ec1f","type":"PanT ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.layouts import gridplot

output_notebook()

x = list(range(11))
y0 = x
y1 = [10 - i for i in x]
y2 = [abs(i - 5) for i in x]

# create three plots
p1 = figure(width=250, plot_height=250, title=None)
p1.circle(x, y0, size=10, color="red")
p2 = figure(width=250, height=250, title=None)
p2.triangle(x, y1, size=10, color="blue")
p3 = figure(width=250, height=250, title=None)
p3.square(x, y2, size=10, color="green")

# make a grid
grid = gridplot([[p1, p2], [None, p3]])

# show the results
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8fb4c7cb-3908-4f02-b150-1eca25120a8e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="fc328a53-08a4-4a0a-86f4-817cfcf0a8e9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#fc328a53-08a4-4a0a-86f4-817cfcf0a8e9").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc328a53-08a4-4a0a-86f4-817cfcf0a8e9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc328a53-08a4-4a0a-86f4-817cfcf0a8e9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"55b28b3c-2004-4635-9298-8a7ea09ea2c1":{"roots":{"references":[{"attributes":{"plot":{"id":"5a1195e9-a2b4-405a-a4f2-942e5ca8e839","subtype":"Figure","type":"Plot"}},"id":"06582037-cb75-4c2c-90f2-7ed5ac05d2f4","type":"ResetTool"},{"attributes":{},"id":"a5dab8bf-8d17-40d3-8f9b-a7cc06fee680","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"
82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                   name
# 0            chevrolet chevelle malibu
# 1                    buick skylark 320
# 2                   plymouth satellite
# 3                        amc rebel sst
# 4                          ford torino
# 5                     ford galaxie 500
# 6                     chevrolet impala
# 7                    plymouth fury iii
# 8                     pontiac catalina
# 9                   amc ambassador dpl
# 10                 dodge challenger se
# 11                  plymouth 'cuda 340
# 12               chevrolet monte carlo
# 13             buick estate wagon (sw)
# 14               toyota corona mark ii
# 15                     plymouth duster
# 16                          amc hornet
# 17                       ford maverick
# 18                        datsun pl510
# 19        volkswagen 1131 deluxe sedan
# 20                         peugeot 504
# 21                         audi 100 ls
# 22                            saab 99e
# 23                            bmw 2002
# 24                         amc gremlin
# 25                           ford f250
# 26                           chevy c20
# 27                          dodge d200
# 28                            hi 1200d
# 29                        datsun pl510
# ..                                 ...
# 362                 chevrolet cavalier
# 363           chevrolet cavalier wagon
# 364          chevrolet cavalier 2-door
# 365         pontiac j2000 se hatchback
# 366                     dodge aries se
# 367                    pontiac phoenix
# 368               ford fairmont futura
# 369                volkswagen rabbit l
# 370                 mazda glc custom l
# 371                   mazda glc custom
# 372             plymouth horizon miser
# 373                     mercury lynx l
# 374                   nissan stanza xe
# 375                       honda accord
# 376                     toyota corolla
# 377                        honda civic
# 378                 honda civic (auto)
# 379                      datsun 310 gx
# 380              buick century limited
# 381  oldsmobile cutlass ciera (diesel)
# 382         chrysler lebaron medallion
# 383                     ford granada l
# 384                   toyota celica gt
# 385                  dodge charger 2.2
# 386                   chevrolet camaro
# 387                    ford mustang gl
# 388                          vw pickup
# 389                      dodge rampage
# 390                        ford ranger
# 391                         chevy s-10
#
# [392 rows x 9 columns]

# %%
df['name']
# Out:
# 0              chevrolet chevelle malibu
# 1                      buick skylark 320
# 2                     plymouth satellite
# 3                          amc rebel sst
# 4                            ford torino
# 5                       ford galaxie 500
# 6                       chevrolet impala
# 7                      plymouth fury iii
# 8                       pontiac catalina
# 9                     amc ambassador dpl
# 10                   dodge challenger se
# 11                    plymouth 'cuda 340
# 12                 chevrolet monte carlo
# 13               buick estate wagon (sw)
# 14                 toyota corona mark ii
# 15                       plymouth duster
# 16                            amc hornet
# 17                         ford maverick
# 18                          datsun pl510
# 19          volkswagen 1131 deluxe sedan
# 20                           peugeot 504
# 21                           audi 100 ls
# 22                              saab 99e
# 23                              bmw 2002
# 24                           amc gremlin
# 25                             ford f250
# 26                             chevy c20
# 27                            dodge d200
# 28                              hi 1200d
# 29                          datsun pl510
#                      ...
# 362                   chevrolet cavalier
# 363             chevrolet cavalier wagon
# 364            chevrolet cavalier 2-door
# 365           pontiac j2000 se hatchback
# 366                       dodge aries se
# 367                      pontiac phoenix
# 368                 ford fairmont futura
# 369                  volkswagen rabbit l
# 370                   mazda glc custom l
# 371                     mazda glc custom
# 372               plymouth horizon miser
# 373                       mercury lynx l
# 374                     nissan stanza xe
# 375                         honda accord
# 376                       toyota corolla
# 377                          honda civic
# 378                   honda civic (auto)
# 379                        datsun 310 gx
# 380                buick century limited
# 381    oldsmobile cutlass ciera (diesel)
# 382           chrysler lebaron medallion
# 383                       ford granada l
# 384                     toyota celica gt
# 385                    dodge charger 2.2
# 386                     chevrolet camaro
# 387                      ford mustang gl
# 388                            vw pickup
# 389                        dodge rampage
# 390                          ford ranger
# 391                           chevy s-10
# Name: name, dtype: object

# %%
df[['mpg','cyl']]
# Out:
#       mpg  cyl
# 0    18.0    8
# 1    15.0    8
# 2    18.0    8
# 3    16.0    8
# 4    17.0    8
# 5    15.0    8
# 6    14.0    8
# 7    14.0    8
# 8    14.0    8
# 9    15.0    8
# 10   15.0    8
# 11   14.0    8
# 12   15.0    8
# 13   14.0    8
# 14   24.0    4
# 15   22.0    6
# 16   18.0    6
# 17   21.0    6
# 18   27.0    4
# 19   26.0    4
# 20   25.0    4
# 21   24.0    4
# 22   25.0    4
# 23   26.0    4
# 24   21.0    6
# 25   10.0    8
# 26   10.0    8
# 27   11.0    8
# 28    9.0    8
# 29   27.0    4
# ..    ...  ...
# 362  28.0    4
# 363  27.0    4
# 364  34.0    4
# 365  31.0    4
# 366  29.0    4
# 367  27.0    4
# 368  24.0    4
# 369  36.0    4
# 370  37.0    4
# 371  31.0    4
# 372  38.0    4
# 373  36.0    4
# 374  36.0    4
# 375  36.0    4
# 376  34.0    4
# 377  38.0    4
# 378  32.0    4
# 379  38.0    4
# 380  25.0    6
# 381  38.0    6
# 382  26.0    4
# 383  22.0    6
# 384  32.0    4
# 385  36.0    4
# 386  27.0    4
# 387  27.0    4
# 388  44.0    4
# 389  32.0    4
# 390  28.0    4
# 391  31.0    4
#
# [392 rows x 2 columns]

# %%
df[['mpg','cyl']][5:10]
# Out:
#     mpg  cyl
# 5  15.0    8
# 6  14.0    8
# 7  14.0    8
# 8  14.0    8
# 9  15.0    8

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook


output_notebook()

p = Scatter(df, x='mpg', y='hp', title="HP vs MPG",
            xlabel="Miles Per Gallon", ylabel="Horsepower")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="05c48a18-9fc1-490f-bf98-b4b7e5976e57">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="20772b36-c271-4461-90d3-bbf4bbcf900e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#20772b36-c271-4461-90d3-bbf4bbcf900e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("20772b36-c271-4461-90d3-bbf4bbcf900e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '20772b36-c271-4461-90d3-bbf4bbcf900e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fe18ec3e-7c4d-4439-be33-75a2d84b18b1":{"roots":{"references":[{"attributes":{},"id":"19fc598b-7a06-408f-8f67-e025234fd9a9","type":"ToolEvents"},{"attributes":{"below":[{"id":"3b6bbe8a-1a40-46da-8b73-7d3ee66ca69a","type":"LinearAxis"}],"left":[{"id":"3597a7d7-28c6-4989-a6ad-4ade0a68ab01","type":"LinearAxis"}],"renderers":[{"id":"aa99a677-3f1a-49df-a536-d532785b2b60","type":"BoxAnnotation"},{"id":"4d26afca-4976-41b4-8133-67ef34575126","type":"GlyphRenderer"},{"id":"36894535-6682-4b03-a471-e36b501f4707","type":"Legend"},{"id":"3b6bbe8a-1a40-46da-8b73-7d3ee66ca69a","type":"LinearAxis"},{"id":"3597a7d7-28c6-4989-a6ad-4ade0a68ab01","type":"LinearAxis"},{"id":"7ae68692-d01b-4c66-bdd7-c1d6fa07d786","type":"Grid"},{"id":"af5953e9-b7cb-42ad-a1fb-4be638e1c6ef","type":"Grid"}],"title":{"id":"b3212d4d-e80d-4356-8433-451b798badbb","type":"Title"},"tool_events":{"id":"19fc598b-7a06-408f-8f67-e025234fd9a9","type":"ToolEvents"},"toolbar":{"id":"41c3e1de-6a68-4026-a1ec-994cbf62716f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"9a27fb95-da23-4c18-8acb-be325431d5d4","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"a4381b4a-3b69-4420-88bd-ef40c5fb827a","type":"Range1d"}},"id":"6d052c16-dadd-4d7e-9ef7-7991db7bfb17","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5b4fbbff-e9ba-4f91-804f-4ae540d9ddf6","type":"PanTool"},{"id":"9616b96c-0924-4e4c-ac37-269f7c0a80b1","type":"WheelZoomTool"},{"id":"dda3b66a-4f3b-451b-b386-83b7f73184f5","type":"BoxZoomTool"},{"id":"b9594fcd-68e8-480c-8f48-863abec6ebca","type":"SaveTool"},{"id":"8c053815-f72a-4cac-a0eb-06e010330a4e","type":"ResetTool"},{"id":"56f7bc78-9840-434e-8530-4d4aa030a4c8","type":"HelpTool"}]},"id":"41c3e1de-6a68-4026-a1ec-994cbf62716f","type":"Toolbar"},{"attributes":{"plot":{"id":"6d052c16-dadd-4d7e-9ef7-7991db7bfb17","subtype":"Chart","type":"Plot"}},"id":"9616b96c-0924-4e4c-ac37-269f7c0a80b1","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aa99a677-3f1a-49df-a536-d532785b2b60","type":"BoxAnnotation"},{"attributes":{},"id":"6d8b51ca-8b38-4be7-b545-0b96fc575962","type":"BasicTicker"},{"attributes":{"plot":{"id":"6d052c16-dadd-4d7e-9ef7-7991db7bfb17","subtype":"Chart","type":"Plot"},"ticker":{"id":"32e5b5d7-7e7d-43d8-9f2d-5f06851ad226","type":"BasicTicker"}},"id":"7ae68692-d01b-4c66-bdd7-c1d6fa07d786","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %%
import pandas
df = pandas.read_csv("universities.csv")
df
# Out:
#                School        Type  Median_SAT  Acceptance_Rate_Perc  \
# 0             Amherst    Lib Arts        1315                    26
# 1             Barnard    Lib Arts        1220                    57
# 2               Bates    Lib Arts        1240                    40
# 3            Berkeley  University        1176                    36
# 4             Bowdoin    Lib Arts        1300                    28
# 5               Brown  University        1281                    23
# 6           Bryn Mawr    Lib Arts        1255                    60
# 7            Cal Tech  University        1400                    30
# 8            Carleton    Lib Arts        1300                    44
# 9     Carnegie Mellon  University        1225                    63
# 10  Claremont McKenna    Lib Arts        1260                    40
# 11              Colby    Lib Arts        1200                    50
# 12            Colgate    Lib Arts        1258                    42
# 13           Columbia  University        1268                    28
# 14            Cornell  University        1280                    29
# 15           Davidson    Lib Arts        1230                    40
# 16               Duke  University        1310                    24
# 17         Georgetown  University        1278                    23
# 18           Grinnell    Lib Arts        1244                    71
# 19           Hamilton    Lib Arts        1215                    42
# 20            Harvard  University        1370                    17
# 21          Haverford    Lib Arts        1285                    39
# 22      Johns Hopkins  University        1290                    47
# 23         Middlebury    Lib Arts        1255                    29
# 24                MIT  University        1357                    29
# 25      Mount Holyoke    Lib Arts        1200                    65
# 26       Northwestern  University        1230                    46
# 27            Oberlin    Lib Arts        1247                    58
# 28         Occidental    Lib Arts        1170                    53
# 29             Pomona    Lib Arts        1320                    37
# 30          Princeton  University        1340                    16
# 31               Rice  University        1327                    23
# 32              Smith    Lib Arts        1195                    61
# 33           Stanford  University        1370                    17
# 34         Swarthnore    Lib Arts        1310                    28
# 35           Syracuse  University        1350                    19
# 36         U Michigan  University        1195                    59
# 37       U of Chicago  University        1300                    44
# 38     U of Rochester  University        1155                    55
# 39     U Pennsylvania  University        1280                    40
# 40               U Va  University        1218                    36
# 41               UCLA  University        1142                    42
# 42                UNC  University        1109                    31
# 43             Vassar    Lib Arts        1287                    47
# 44  Washington U (MO)  University        1225                    53
# 45  Washinton and Lee    Lib Arts        1234                    33
# 46          Wellesley    Lib Arts        1250                    53
# 47      Wesleyan (CT)    Lib Arts        1290                    39
# 48           Williams    Lib Arts        1336                    32
# 49               Yale  University        1350                    18
#
#    Expenditures_per_Student  Graduation_perc
# 0                  $23,972                93
# 1                  $15,887                80
# 2                  $15,798                88
# 3                  $26,031                68
# 4                  $23,132                90
# 5                  $26,621                90
# 6                  $16,962                84
# 7                 $112,488                75
# 8                  $14,313                80
# 9                  $36,967                77
# 10                 $18,339                74
# 11                 $16,984                84
# 12                 $15,768                85
# 13                 $50,466                90
# 14                 $40,850                83
# 15                 $15,948                89
# 16                 $43,454                91
# 17                 $25,426                89
# 18                 $20,070                73
# 19                 $18,649                85
# 20                 $51,609                90
# 21                 $17,476                87
# 22                 $50,006                86
# 23                 $22,246                92
# 24                 $62,442                86
# 25                 $21,022                83
# 26                 $31,736                82
# 27                 $21,231                77
# 28                 $18,172                72
# 29                 $24,001                80
# 30                 $52,935                93
# 31                 $29,403                88
# 32                 $22,743                87
# 33                 $68,113                88
# 34                 $24,738                88
# 35                 $36,850                90
# 36                 $24,038                77
# 37                 $42,830                73
# 38                 $42,456                73
# 39                 $33,970                86
# 40                 $21,301                88
# 41                 $29,544                61
# 42                 $21,652                73
# 43                 $18,161                84
# 44                 $43,871                76
# 45                 $16,198                78
# 46                 $25,091                86
# 47                 $17,953                91
# 48                 $21,394                93
# 49                 $57,714                93

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook

output_notebook()


p = Scatter(df, x='Acceptance_Rate_Perc', y='Median_SAT', title="Universities",
            xlabel="Acceptance Rate", ylabel="Media SAT")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2c22bdef-05c8-46fc-ba2c-c11aa0356149">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="b8fa7c2b-6b63-4f07-a2db-ac88813ec275"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b8fa7c2b-6b63-4f07-a2db-ac88813ec275").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b8fa7c2b-6b63-4f07-a2db-ac88813ec275");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b8fa7c2b-6b63-4f07-a2db-ac88813ec275' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"10ad0479-d920-49be-a47a-c7e86b0b53c2":{"roots":{"references":[{"attributes":{"plot":{"id":"c9d96207-39dd-4d53-bfcb-5720cfaaed6d","subtype":"Chart","type":"Plot"}},"id":"4423eefd-2452-4160-89f9-56b340c50a4c","type":"HelpTool"},{"attributes":{"overlay":{"id":"6a3f9cd1-8cb8-42e9-a87e-c42ac8b870c8","type":"BoxAnnotation"},"plot":{"id":"c9d96207-39dd-4d53-bfcb-5720cfaaed6d","subtype":"Chart","type":"Plot"}},"id":"955644bb-75d2-48de-8174-8673996a6842","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[26,57,40,36,28,23,60,30,44,63,40,50,42,28,29,40,24,23,71,42,17,39,47,29,29,65,46,58,53,37,16,23,61,17,28,19,59,44,55,40,36,42,31,47,53,33,53,39,32,18],"y_values":[1315,1220,1240,1176,1300,1281,1255,1400,1300,1225,1260,1200,1258,1268,1280,1230,1310,1278,1244,1215,1370,1285,1290,1255,1357,1200,1230,1247,1170,1320,1340,1327,1195,1370,1310,1350,1195,1300,1155,1280,1218,1142,1109,1287,1225,1234,1250,1290,1336,1350]}},"id":"a03666e2-d384-45d8-8d22-c4686f9bbcc1","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6a3f9cd1-8cb8-42e9-a87e-c42ac8b870c8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"c9d96207-39dd-4d53-bfcb-5720cfaaed6d","subtype":"Chart","type":"Plot"}},"id":"503e88c1-0a6c-4e84-a31d-2cc52433cd2d","type":"SaveTool"},{"attributes":{},"id":"f1340d3f-6e29-4b61-8d57-863deb2e68ef","type":"ToolEvents"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"45aaa9b5-1fb8-4015-b04e-e6fb116647fd","type":"Range1d"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"3b4a5729-ae69-404c-9106-337c74719482","type":"Range1d"},{"attributes":{},"id":"37b46e77-5752-4d11-a8fe-197e96a0a461","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"099bfd78-331e-4bde-8160-8d25e3663b18","type":"PanTool"},{"id":"664841da-1d5f-4998-9971-56cb92441dac","type":"WheelZoomTool"},{"id":"955644bb-75d2-48de-8174-8673996a6842","type":"BoxZoomTool"},{"id":"503e88c1-0a6c-4e84-a31d-2cc52433cd2d","type":"SaveTool"},{"id":"8dcd7966-1444-4522-9155-abf9f4c5d9f5","type":"ResetTool"},{"id":"4423eefd-2452-4160-89f9-56b340c50a4c","type":"HelpTool"}]},"id":"0d373e62-1236-4138-9967-3ba221ddbd89","type":"Toolbar"},{"attributes":{"location":"top_left","plot":{"id":"c9d96207-39dd-4d53-bfcb-5720cfaaed6d","subtype":"Chart","type":"Plot"}},"id":"dd7834de-5ce7-45fc-9b78-7309deac4eed","type":"Legend"},{"attributes":{"plot":{"id":"c9d96207-39dd-4d53-bfcb-5720cfaaed6d","subtype":"Chart","type":"Plot"}},"id":"099bfd78-331e-4bde-8160-8d25e3663b18","type":"PanTool"},{"attributes":{},"id":"0a0cf265-2b77-4fb0-acf2-824c7095eaea","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Universities"},"id":"f143f19f-a018-4f04-adfb-5e7d27ee4453","type":"Title"},{"attributes":{"data_source":{"id":"a03666e2-d384-45d8-8d22-c4686f9bbcc1","type":"ColumnDataSource"},"glyph":{"id":"9e44e717-868b-44e8-95b2-6ececb282f0d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d65beb12-2f1b-45bf-9e61-0c9c56022e6f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9e44e717-868b-44e8-95b2-6ececb282f0d","type":"Circle"},{"attributes":{"plot":{"id":"c9d96207-39dd-4 ...

# %%
p = Scatter(df, x='Acceptance_Rate_Perc', y='Graduation_perc', title="Universities",
            xlabel="Acceptance Rate", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1c2b9a87-2081-4aa4-b5fd-c3dad0291841"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1c2b9a87-2081-4aa4-b5fd-c3dad0291841").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c2b9a87-2081-4aa4-b5fd-c3dad0291841");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c2b9a87-2081-4aa4-b5fd-c3dad0291841' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"572af2b9-38f4-4aea-b756-9e56cf277e6f":{"roots":{"references":[{"attributes":{"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"},"ticker":{"id":"5137272f-a599-4b75-9bb5-ca169ca9515b","type":"BasicTicker"}},"id":"a8a85b8a-dd60-4f23-9543-139391379711","type":"Grid"},{"attributes":{"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"}},"id":"351b8a29-137e-4bd6-a75c-14188ffd10dc","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5465d0c1-c3d9-48f1-a4fb-b44f0b1b3ead","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"},"ticker":{"id":"ec399893-cd25-4840-a41a-40e66c9a8b9c","type":"BasicTicker"}},"id":"2dc41d8e-5768-4085-bbb2-117ba39f7dbe","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"351b8a29-137e-4bd6-a75c-14188ffd10dc","type":"PanTool"},{"id":"1cd7da22-290e-4265-acb4-d05c83c0772e","type":"WheelZoomTool"},{"id":"a953129c-d2b4-4754-9d54-e4f72ca272af","type":"BoxZoomTool"},{"id":"406282d1-00f8-4621-a1b3-03e04d85fd86","type":"SaveTool"},{"id":"297ddac0-24e5-493e-9a07-4a2f971f9a8e","type":"ResetTool"},{"id":"c5441ec9-b6bd-46c8-993c-9e926cba7480","type":"HelpTool"}]},"id":"5673ec4e-0bcb-4a40-bd1b-89c150795ae2","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[26,57,40,36,28,23,60,30,44,63,40,50,42,28,29,40,24,23,71,42,17,39,47,29,29,65,46,58,53,37,16,23,61,17,28,19,59,44,55,40,36,42,31,47,53,33,53,39,32,18],"y_values":[93,80,88,68,90,90,84,75,80,77,74,84,85,90,83,89,91,89,73,85,90,87,86,92,86,83,82,77,72,80,93,88,87,88,88,90,77,73,73,86,88,61,73,84,76,78,86,91,93,93]}},"id":"40113c6b-c2f8-4799-bd4c-fc157f94fc60","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"5465d0c1-c3d9-48f1-a4fb-b44f0b1b3ead","type":"BoxAnnotation"},"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"}},"id":"a953129c-d2b4-4754-9d54-e4f72ca272af","type":"BoxZoomTool"},{"attributes":{},"id":"d2ac79ca-1cfd-4567-b0ad-be428fea12d5","type":"BasicTickFormatter"},{"attributes":{},"id":"2d1d1ff6-6d76-455f-a493-c25147daafec","type":"ToolEvents"},{"attributes":{"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"}},"id":"c5441ec9-b6bd-46c8-993c-9e926cba7480","type":"HelpTool"},{"attributes":{"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"}},"id":"406282d1-00f8-4621-a1b3-03e04d85fd86","type":"SaveTool"},{"attributes":{"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"}},"id":"1cd7da22-290e-4265-acb4-d05c83c0772e","type":"WheelZoomTool"},{"attributes":{},"id":"5137272f-a599-4b75-9bb5-ca169ca9515b","type":"BasicTicker"},{"attributes":{"axis_label":"Acceptance Rate","formatter":{"id":"18a62b82-2816-4383-a255-6547a83feee5","type":"BasicTickFormatter"},"plot":{"id":"a0a66cf9-8043-4be8-b8ed-3bf0e9847c91","subtype":"Chart","type":"Plot"},"ticker":{"id":"5137272f-a599-4b75-9bb5-ca169ca9515b","type":"BasicTicker"}},"id":"83518a5b-f934-4c04-ae62-c4206f7382c0","type":"LinearAxis"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"304df389-1cf7-4c59-a52e-ba8cd107c20a","type":"Range1d"},{"attributes":{"plot":null,"text":"Universities"},"id":"17d8197e-3c12-4c76-8f4e-ceb7ac8aa3d1","type":"Title"}, ...

# %%
p = Scatter(df, x='Median_SAT', y='Graduation_perc', title="Universities",
            xlabel="Median_SAT", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="041d0222-d58d-4177-9e7c-f9832969a03a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#041d0222-d58d-4177-9e7c-f9832969a03a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("041d0222-d58d-4177-9e7c-f9832969a03a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '041d0222-d58d-4177-9e7c-f9832969a03a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"13327858-7d4c-4763-aa72-65ec673b7ac5":{"roots":{"references":[{"attributes":{},"id":"a893bc04-8988-406e-a977-84c1dab3f97d","type":"ToolEvents"},{"attributes":{"callback":null,"end":96.2,"start":57.8},"id":"8a987d04-5e64-4422-84da-43d2201d228d","type":"Range1d"},{"attributes":{"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"},"ticker":{"id":"1cb0aa8c-0d26-4f70-a0be-30ef66e9ba10","type":"BasicTicker"}},"id":"baf74644-8619-438b-954e-5c449969667e","type":"Grid"},{"attributes":{"location":"top_left","plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"}},"id":"ac35cdc0-b54e-4bd9-81a3-26565c74f33e","type":"Legend"},{"attributes":{"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"}},"id":"b025f605-3990-43f3-9906-f67613c97e7a","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"80f5917f-d908-4e31-bcc0-76c1cb110c10","type":"Circle"},{"attributes":{},"id":"f059ccfc-b441-49e7-b3a9-c137842c5d8e","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"a33e00b6-2a0a-400c-919e-3a39081237dc","type":"BoxAnnotation"},"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"}},"id":"082a610b-1923-42df-8b67-d3bb8cbd20cf","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a33e00b6-2a0a-400c-919e-3a39081237dc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"}},"id":"6b34b3a2-e10a-4cd4-995e-98c3e8bf7c16","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"529c86ff-a86f-4ac7-99aa-a58ccbd2ae65","type":"PanTool"},{"id":"b025f605-3990-43f3-9906-f67613c97e7a","type":"WheelZoomTool"},{"id":"082a610b-1923-42df-8b67-d3bb8cbd20cf","type":"BoxZoomTool"},{"id":"6b34b3a2-e10a-4cd4-995e-98c3e8bf7c16","type":"SaveTool"},{"id":"866b19ab-8ea3-4b4f-93f3-d618808ee1f3","type":"ResetTool"},{"id":"3b79094f-8ac1-48d5-9b99-3755499427d7","type":"HelpTool"}]},"id":"d4890e23-0191-4d55-8d1f-7e7ccffeb2d2","type":"Toolbar"},{"attributes":{"axis_label":"Median_SAT","formatter":{"id":"f059ccfc-b441-49e7-b3a9-c137842c5d8e","type":"BasicTickFormatter"},"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"},"ticker":{"id":"1cb0aa8c-0d26-4f70-a0be-30ef66e9ba10","type":"BasicTicker"}},"id":"9406336a-72b9-43bf-b89d-f87bb07565a9","type":"LinearAxis"},{"attributes":{},"id":"3a7a9538-d558-4c5b-a63d-ea1d58b39695","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Universities"},"id":"74958b1b-1143-4454-b4d1-fdb75d14f23c","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"},"ticker":{"id":"c77099a9-71f3-40ae-a9ba-efca728c4d2b","type":"BasicTicker"}},"id":"72dee44f-ade4-4542-8f2c-c0cda98b9e1a","type":"Grid"},{"attributes":{"axis_label":"Graduation_perc","formatter":{"id":"3a7a9538-d558-4c5b-a63d-ea1d58b39695","type":"BasicTickFormatter"},"plot":{"id":"9b8df45c-578a-4937-b698-9729c5abdeca","subtype":"Chart","type":"Plot"},"ticker":{"id":"c77099a9-71f3-40ae-a9ba-efca728c4d2b","type":"BasicTicker"}},"id":"ea94609b-65a5-4459-abd8-c313c9faa767","type":"LinearAxis"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"836cde31-c51f-4c90-95e7-24031c4b9bc6","type":"Range1d"},{"attributes":{"below":[{"id":"9406336a-72b9-43bf-b89d-f87bb07565a9","type":"LinearAxis"}],"left":[{"id":"ea94609b-65a5-4459-abd8-c313c9faa767","ty ...

# %%
from bokeh.charts import Scatter
from bokeh.io import show, output_notebook

output_notebook()

p1 = Scatter(df, x='Acceptance_Rate_Perc', y='Median_SAT', title="Universities",
            xlabel="Acceptance Rate", ylabel="Media SAT", width=250, plot_height=250)

p2 = Scatter(df, x='Acceptance_Rate_Perc', y='Graduation_perc', title="Universities",
            xlabel="Acceptance Rate", ylabel="Graduation_perc", width=250, plot_height=250)

p3 = Scatter(df, x='Median_SAT', y='Graduation_perc', title="Universities",
            xlabel="Median_SAT", ylabel="Graduation_perc", width=250, plot_height=250)

# make a grid
grid = gridplot([[p1, p2], [p3,]])

# show the results
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="84dccadc-7d1e-45a5-8c36-9f4649142953">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="a3268b60-f6cc-4fcb-be90-9665a5e42c6a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a3268b60-f6cc-4fcb-be90-9665a5e42c6a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3268b60-f6cc-4fcb-be90-9665a5e42c6a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3268b60-f6cc-4fcb-be90-9665a5e42c6a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ab2b7f33-c773-4f1b-a570-6af3597b39fd":{"roots":{"references":[{"attributes":{},"id":"b9082ea1-5d44-48c0-87e2-de279c6b89d9","type":"BasicTicker"},{"attributes":{"axis_label":"Graduation_perc","formatter":{"id":"c391502a-b511-4e22-8ebc-956422c02103","type":"BasicTickFormatter"},"plot":{"id":"4a5d92f0-ac1e-4011-bb4c-33cf032faa21","subtype":"Chart","type":"Plot"},"ticker":{"id":"2148f1b1-8027-4c98-a137-c7a3435fb61f","type":"BasicTicker"}},"id":"27909d9f-71a2-42bb-b404-b64f91b6698f","type":"LinearAxis"},{"attributes":{"plot":{"id":"4a5d92f0-ac1e-4011-bb4c-33cf032faa21","subtype":"Chart","type":"Plot"},"ticker":{"id":"6bc9d40f-5693-4d1f-a15f-6b05c9ec0fe3","type":"BasicTicker"}},"id":"d80af3f3-4ece-4e72-af13-93e07e694930","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ee919dd7-84f9-4ca2-839c-3501ded1e017","type":"PanTool"},{"id":"f25fa901-d639-422c-9dfe-7fe23c4f12d0","type":"WheelZoomTool"},{"id":"2be6ddad-701c-4049-b3c3-ab03cbd2e38f","type":"BoxZoomTool"},{"id":"4dae4b2c-cdfb-425f-835c-4ded95055608","type":"SaveTool"},{"id":"70a00bb7-1afe-480e-98fb-588093d00c38","type":"ResetTool"},{"id":"53cc3c69-adc4-4b7f-9b81-1ae039e66085","type":"HelpTool"}]},"id":"b1c756eb-3aa1-40f6-940a-823c3c0e5ea3","type":"Toolbar"},{"attributes":{"children":[{"id":"f7ef2911-98f3-4f0d-b446-f2484a8b7a3a","subtype":"Chart","type":"Plot"},{"id":"05cf5ded-7bdd-4f70-920e-b68f0e4e7c00","subtype":"Chart","type":"Plot"}]},"id":"7d892e70-7ff6-4bbf-9785-56a4496568b4","type":"Row"},{"attributes":{},"id":"6b48f536-2d26-4ef0-a5ea-8af0dbd80140","type":"BasicTicker"},{"attributes":{},"id":"95e5c624-e1f7-4497-9bd9-f62c0d4f074b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"05cf5ded-7bdd-4f70-920e-b68f0e4e7c00","subtype":"Chart","type":"Plot"},"ticker":{"id":"b9082ea1-5d44-48c0-87e2-de279c6b89d9","type":"BasicTicker"}},"id":"88859b2b-6608-4be5-b192-ed0cb780fdef","type":"Grid"},{"attributes":{"axis_label":"Acceptance Rate","formatter":{"id":"95e5c624-e1f7-4497-9bd9-f62c0d4f074b","type":"BasicTickFormatter"},"plot":{"id":"f7ef2911-98f3-4f0d-b446-f2484a8b7a3a","subtype":"Chart","type":"Plot"},"ticker":{"id":"74a9f7fa-7005-4a40-9b45-6fe34e566a5f","type":"BasicTicker"}},"id":"8b2bd9b6-3225-4cca-9c12-423a8d579897","type":"LinearAxis"},{"attributes":{"plot":{"id":"05cf5ded-7bdd-4f70-920e-b68f0e4e7c00","subtype":"Chart","type":"Plot"}},"id":"c0a79fcf-d12e-4cce-83e4-5348a37971ad","type":"PanTool"},{"attributes":{"plot":{"id":"f7ef2911-98f3-4f0d-b446-f2484a8b7a3a","subtype":"Chart","type":"Plot"}},"id":"174030f0-3b8d-4399-8d4d-26c9d1702c23","type":"SaveTool"},{"attributes":{"axis_label":"Media SAT","formatter":{"id":"dce7d02c-09b9-4962-80ec-3b37224857bd","type":"BasicTickFormatter"},"plot":{"id":"f7ef2911-98f3-4f0d-b446-f2484a8b7a3a","subtype":"Chart","type":"Plot"},"ticker":{"id":"6b48f536-2d26-4ef0-a5ea-8af0dbd80140","type":"BasicTicker"}},"id":"b33bb5f3-0c78-43fa-9160-455eef6a6d11","type":"LinearAxis"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"3ab40ccf-d799-4a52-a4c3-9629e10bd685","type":"Range1d"},{"attributes":{"below":[{"id":"cd023ba1-e41e-4aa8-b47d-e73f8a9b3eb7","type":"LinearAxis"}],"left":[{"id":"27909d9f-71a2-42bb-b404-b64f91b6698f","type":"LinearAxis"}],"plot_height":250,"renderers":[{"id":"b1093d93-7f93-477b-9457-948a8b01bca9","type":"BoxAnnotation"},{"id":"cf176a3a-885d-4737-b797-6d9484c4502d","type":"GlyphRenderer"},{"id":"5b5d8ae3-3d01-47e5-ac7b-543c6786acea","type":"Legend"},{"id":"cd023ba1-e41e-4aa8-b47d-e73f8a9b3eb7","type":"LinearAxis"},{"id":"27909d9f-71a2-42bb-b404-b64f91b6698f","type":"LinearAxis"},{"id":"d80af3f3-4ece-4e72-af13-93e07e694930","type":"Grid"},{"id":"2633eda0-87f6-4268-b33b-a83bdee96e9c","type":"Grid"}],"title":{"id":"880c708b-910c-4580-8bd4-a777076a5a50","type":"Title"},"tool_events":{"id":"97001168-e540-44e4-943d-2d77419df852","type":"ToolEvents"},"toolbar":{"id":"b1c756eb-3aa1-40f6-940a-823c3c0e5ea3","type":"Toolbar"}," ...
