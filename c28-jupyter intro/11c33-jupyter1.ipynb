# %% [markdown]
# # Demos
#
# Let's run a few demos to test our installation.
#
# First, note that this cell is a "markdown" cell. Each cell can be specified as a type. The default is to assume it is a "code" cell. You can change this type setting by selecting the cell you want to change and going into the cell->Cell Type menu.
#
# Now, let's try a few demos....

# %%
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook
output_notebook()

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
t=show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="29f01f26-0c41-4412-811e-e108ce067257">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3cc5dae5-1be9-4ea4-a401-d87b753ceceb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("3cc5dae5-1be9-4ea4-a401-d87b753ceceb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3cc5dae5-1be9-4ea4-a401-d87b753ceceb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3cc5dae5-1be9-4ea4-a401-d87b753ceceb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2dbc52d8-a7dc-4f4b-af14-8cad9a905fd2":{"roots":{"references":[{"attributes":{"label":{"value":"Temp."},"renderers":[{"id":"6b3525d5-aea8-4df2-8ac5-e51333cf6246","type":"GlyphRenderer"}]},"id":"0b165b99-48fc-44f0-9596-88c149466510","type":"LegendItem"},{"attributes":{"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"94c326b6-bcc1-4788-9857-7796f2239054","type":"PanTool"},{"attributes":{"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"04c3ccb5-73bf-4043-b200-20d96fe73ddc","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"94c326b6-bcc1-4788-9857-7796f2239054","type":"PanTool"},{"id":"04c3ccb5-73bf-4043-b200-20d96fe73ddc","type":"WheelZoomTool"},{"id":"a8277dad-830d-45cc-bf16-56ac0c033b2f","type":"BoxZoomTool"},{"id":"4f033ed7-2b51-482d-8272-d581d54a3fda","type":"SaveTool"},{"id":"a04fcb9f-c5ba-4151-a1a5-9fa95b3f18df","type":"ResetTool"},{"id":"5d54416e-6448-465c-ae85-febbdb40592e","type":"HelpTool"}]},"id":"4f63cb36-5b3f-4d0a-9cef-a6c8a77dd261","type":"Toolbar"},{"attributes":{"overlay":{"id":"49f2e30d-74d0-4d51-96e9-8ea32427411f","type":"BoxAnnotation"},"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"a8277dad-830d-45cc-bf16-56ac0c033b2f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"4f033ed7-2b51-482d-8272-d581d54a3fda","type":"SaveTool"},{"attributes":{"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"a04fcb9f-c5ba-4151-a1a5-9fa95b3f18df","type":"ResetTool"},{"attributes":{"plot":{"id":"2175471e-ab8c-4049-a847-b62ecc0df3ab","subtype":"Figure","type":"Plot"}},"id":"5d54416e-6448-465c-ae85-febbdb40592e","type":"HelpTool"},{"attributes":{"data_source":{"id":"10e990c1-92ce-41d2-aa94-c32548c5de91","type":"ColumnDataSource"},"glyph":{"id":"6bc9fe21-f94b-42f0-84ee-e25aca972a5b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b03a9c40-b813-4df5-8e21-3560f6f08c63","type":"Line"},"selection_glyph":null},"id":"6b3525d5-aea8-4df2-8ac5-e51333cf6246","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"67d5e0ce-822a-4a43-879f-d85b83d76bf1","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b03a9c40-b813-4df5-8e21-3560f6f08c63","type":"Line"},{"attributes":{},"id":"87820f3c-e93b-4a63-9326-88fd3b217781","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"49f2e30d-74d0-4d51-96e9-8ea32427411f","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"de421649-e5c6-4c14-88c5-cc0e616c52b2","type":"LinearAxis"}],"left":[{"id":"1cb6e1c1-7f1f-4016-82dc-786c0fd57725","type":"LinearAxis"}],"renderers":[{"id":"de421649-e5c6-4c14-88c5-cc0e616c52b2","type":"LinearAxis"},{"id":"d9bfccd0-c699-46c4-aeae-a7479321ad1a","type":"Grid"},{"id":"1cb6e1c1-7f1f-4016-82dc-786c0fd57725","type":"LinearAxis"},{"id":"52e04624-4980-4e72-a758-1a4b9ed9532a","type":"Grid"},{"id":"49f2e30d-74d0-4d51-96e9-8ea32427411f","type":"BoxAnnotation"},{"id":"c7d03ca1-f966-472b-9606-8163a3be26c6","type":"Legend"},{"id":"6b3525d5-aea8-4df2-8ac5-e51333cf6246","type":"GlyphRenderer"}],"title":{"id":"becf6842-e028-49f7-a777-dd8a8398b097","type":"Title"},"tool_events":{"id":"87820f3c-e93b-4a63-9326-88fd3b217781","type":"ToolEvents"},"toolbar":{"id":"4f63cb36-5b3f-4d0a-9cef-a6c8a77dd261","type":"Toolbar"},"x_range":{"id":"67d5e0ce-822a-4a43-879f-d85b83d76bf1","type":"DataRange1d"},"y_range":{"id":"9e880b3b-d901-4de1-83e1-e ...

# %%
from bokeh.sampledata.autompg import autompg as df
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 6    14.0    8  454.0  220    4354    9.0  70       1
# 7    14.0    8  440.0  215    4312    8.5  70       1
# 8    14.0    8  455.0  225    4425   10.0  70       1
# 9    15.0    8  390.0  190    3850    8.5  70       1
# 10   15.0    8  383.0  170    3563   10.0  70       1
# 11   14.0    8  340.0  160    3609    8.0  70       1
# 12   15.0    8  400.0  150    3761    9.5  70       1
# 13   14.0    8  455.0  225    3086   10.0  70       1
# 14   24.0    4  113.0   95    2372   15.0  70       3
# 15   22.0    6  198.0   95    2833   15.5  70       1
# 16   18.0    6  199.0   97    2774   15.5  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 18   27.0    4   97.0   88    2130   14.5  70       3
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 20   25.0    4  110.0   87    2672   17.5  70       2
# 21   24.0    4  107.0   90    2430   14.5  70       2
# 22   25.0    4  104.0   95    2375   17.5  70       2
# 23   26.0    4  121.0  113    2234   12.5  70       2
# 24   21.0    6  199.0   90    2648   15.0  70       1
# 25   10.0    8  360.0  215    4615   14.0  70       1
# 26   10.0    8  307.0  200    4376   15.0  70       1
# 27   11.0    8  318.0  210    4382   13.5  70       1
# 28    9.0    8  304.0  193    4732   18.5  70       1
# 29   27.0    4   97.0   88    2130   14.5  71       3
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 362  28.0    4  112.0   88    2605   19.6  82       1
# 363  27.0    4  112.0   88    2640   18.6  82       1
# 364  34.0    4  112.0   88    2395   18.0  82       1
# 365  31.0    4  112.0   85    2575   16.2  82       1
# 366  29.0    4  135.0   84    2525   16.0  82       1
# 367  27.0    4  151.0   90    2735   18.0  82       1
# 368  24.0    4  140.0   92    2865   16.4  82       1
# 369  36.0    4  105.0   74    1980   15.3  82       2
# 370  37.0    4   91.0   68    2025   18.2  82       3
# 371  31.0    4   91.0   68    1970   17.6  82       3
# 372  38.0    4  105.0   63    2125   14.7  82       1
# 373  36.0    4   98.0   70    2125   17.3  82       1
# 374  36.0    4  120.0   88    2160   14.5  82       3
# 375  36.0    4  107.0   75    2205   14.5  82       3
# 376  34.0    4  108.0   70    2245   16.9  82       3
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 379  38.0    4   91.0   67    1995   16.2  82       3
# 380  25.0    6  181.0  110    2945   16.4  82       1
# 381  38.0    6  262.0   85    3015   17.0  82       1
# 382  26.0    4  156.0   92    2585   14.5  82       1
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 384  32.0    4  144.0   96    2665   13.9  82       3
# 385  36.0    4  135.0   84    2370   13.0  82       1
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                   name
# 0            chevrolet chevelle malibu
# 1                    buick skylark 320
# 2                   plymouth satellite
# 3                        amc rebel sst
# 4                          ford torino
# 5                     ford galaxie 500
# 6                     chevrolet impala
# 7                    plymouth fury iii
# 8                     pontiac catalina
# 9                   amc ambassador dpl
# 10                 dodge challenger se
# 11                  plymouth 'cuda 340
# 12               chevrolet monte carlo
# 13             buick estate wagon (sw)
# 14               toyota corona mark ii
# 15                     plymouth duster
# 16                          amc hornet
# 17                       ford maverick
# 18                        datsun pl510
# 19        volkswagen 1131 deluxe sedan
# 20                         peugeot 504
# 21                         audi 100 ls
# 22                            saab 99e
# 23                            bmw 2002
# 24                         amc gremlin
# 25                           ford f250
# 26                           chevy c20
# 27                          dodge d200
# 28                            hi 1200d
# 29                        datsun pl510
# ..                                 ...
# 362                 chevrolet cavalier
# 363           chevrolet cavalier wagon
# 364          chevrolet cavalier 2-door
# 365         pontiac j2000 se hatchback
# 366                     dodge aries se
# 367                    pontiac phoenix
# 368               ford fairmont futura
# 369                volkswagen rabbit l
# 370                 mazda glc custom l
# 371                   mazda glc custom
# 372             plymouth horizon miser
# 373                     mercury lynx l
# 374                   nissan stanza xe
# 375                       honda accord
# 376                     toyota corolla
# 377                        honda civic
# 378                 honda civic (auto)
# 379                      datsun 310 gx
# 380              buick century limited
# 381  oldsmobile cutlass ciera (diesel)
# 382         chrysler lebaron medallion
# 383                     ford granada l
# 384                   toyota celica gt
# 385                  dodge charger 2.2
# 386                   chevrolet camaro
# 387                    ford mustang gl
# 388                          vw pickup
# 389                      dodge rampage
# 390                        ford ranger
# 391                         chevy s-10
#
# [392 rows x 9 columns]

# %%
from bokeh.charts import Scatter, output_file, show
output_notebook()
p = Scatter(df, x='mpg', y='hp', title="HP vs MPG",
            xlabel="Miles Per Gallon", ylabel="Horsepower")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="610386ec-752c-4eb3-8a57-5b0a56260f33">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b0b2147d-9282-4cd1-bad5-d38c6426d864"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b0b2147d-9282-4cd1-bad5-d38c6426d864").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b0b2147d-9282-4cd1-bad5-d38c6426d864");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b0b2147d-9282-4cd1-bad5-d38c6426d864' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"23ee9984-a452-40b3-8798-1b364c575de2":{"roots":{"references":[{"attributes":{},"id":"edeaf2a3-fbf8-438b-bfd2-b7f2e6825c93","type":"BasicTickFormatter"},{"attributes":{},"id":"1c72bc4e-7d6d-4f3c-b6bd-91f5906a7a98","type":"ToolEvents"},{"attributes":{"below":[{"id":"e96768b6-e4be-459d-ad23-9dc987a1e909","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"f78a2cc9-db19-48f9-93e7-ada707d38552","type":"LinearAxis"}],"renderers":[{"id":"e03a085b-c566-40f1-a745-20ca8279782f","type":"BoxAnnotation"},{"id":"59aea6c0-a36f-40d3-a124-e027bcc14f22","type":"GlyphRenderer"},{"id":"7630e85b-4b15-4930-b8cc-d3f2faa82789","type":"Legend"},{"id":"e96768b6-e4be-459d-ad23-9dc987a1e909","type":"LinearAxis"},{"id":"f78a2cc9-db19-48f9-93e7-ada707d38552","type":"LinearAxis"},{"id":"747b0bfb-19a1-4651-b976-5c996fb15276","type":"Grid"},{"id":"63a5d62b-1ca1-4bb4-9310-e18d441c434b","type":"Grid"}],"title":{"id":"60f94913-611c-4be0-8430-e66b5e882cf7","type":"Title"},"tool_events":{"id":"1c72bc4e-7d6d-4f3c-b6bd-91f5906a7a98","type":"ToolEvents"},"toolbar":{"id":"f60aec48-fb8f-43aa-a664-012685ef54f7","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0d0f6261-0797-4098-a8dd-edacb48e449b","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"b592938b-7c3b-4ca3-a601-b23bb391366b","type":"Range1d"}},"id":"ac1c0f36-e48c-4515-ae19-d692d218cf9c","subtype":"Chart","type":"Plot"},{"attributes":{"plot":null,"text":"HP vs MPG"},"id":"60f94913-611c-4be0-8430-e66b5e882cf7","type":"Title"},{"attributes":{"callback":null,"end":248.4,"start":27.599999999999998},"id":"b592938b-7c3b-4ca3-a601-b23bb391366b","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"69824dba-3b26-401e-9eb8-e0a5bdd073a5","type":"PanTool"},{"id":"a90f4622-b592-43d8-9f3d-cd7362893b61","type":"WheelZoomTool"},{"id":"04fcc399-0e62-4839-a286-6b64175bfae3","type":"BoxZoomTool"},{"id":"f0ea2047-724b-487e-8f05-404631f37bf4","type":"SaveTool"},{"id":"9ec22266-1b59-448d-a97f-4fffa53778e7","type":"ResetTool"},{"id":"6114779d-dab0-4102-b66e-6a9f13c4be93","type":"HelpTool"}]},"id":"f60aec48-fb8f-43aa-a664-012685ef54f7","type":"Toolbar"},{"attributes":{"location":"top_left","plot":{"id":"ac1c0f36-e48c-4515-ae19-d692d218cf9c","subtype":"Chart","type":"Plot"}},"id":"7630e85b-4b15-4930-b8cc-d3f2faa82789","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e03a085b-c566-40f1-a745-20ca8279782f","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"02f35baa-12b6-4633-a9e0-0bc2519eab82","type":"ColumnDataSource"},"glyph":{"id":"b0671ed3-9fec-4ddf-870b-38c152339ba0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"59aea6c0-a36f-40d3-a124-e027bcc14f22","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %%
import pandas
df = pandas.read_csv("universities.csv")
df
# Out:
#                School        Type  Median_SAT  Acceptance_Rate_Perc  \
# 0             Amherst    Lib Arts        1315                    26
# 1             Barnard    Lib Arts        1220                    57
# 2               Bates    Lib Arts        1240                    40
# 3            Berkeley  University        1176                    36
# 4             Bowdoin    Lib Arts        1300                    28
# 5               Brown  University        1281                    23
# 6           Bryn Mawr    Lib Arts        1255                    60
# 7            Cal Tech  University        1400                    30
# 8            Carleton    Lib Arts        1300                    44
# 9     Carnegie Mellon  University        1225                    63
# 10  Claremont McKenna    Lib Arts        1260                    40
# 11              Colby    Lib Arts        1200                    50
# 12            Colgate    Lib Arts        1258                    42
# 13           Columbia  University        1268                    28
# 14            Cornell  University        1280                    29
# 15           Davidson    Lib Arts        1230                    40
# 16               Duke  University        1310                    24
# 17         Georgetown  University        1278                    23
# 18           Grinnell    Lib Arts        1244                    71
# 19           Hamilton    Lib Arts        1215                    42
# 20            Harvard  University        1370                    17
# 21          Haverford    Lib Arts        1285                    39
# 22      Johns Hopkins  University        1290                    47
# 23         Middlebury    Lib Arts        1255                    29
# 24                MIT  University        1357                    29
# 25      Mount Holyoke    Lib Arts        1200                    65
# 26       Northwestern  University        1230                    46
# 27            Oberlin    Lib Arts        1247                    58
# 28         Occidental    Lib Arts        1170                    53
# 29             Pomona    Lib Arts        1320                    37
# 30          Princeton  University        1340                    16
# 31               Rice  University        1327                    23
# 32              Smith    Lib Arts        1195                    61
# 33           Stanford  University        1370                    17
# 34         Swarthnore    Lib Arts        1310                    28
# 35           Syracuse  University        1350                    19
# 36         U Michigan  University        1195                    59
# 37       U of Chicago  University        1300                    44
# 38     U of Rochester  University        1155                    55
# 39     U Pennsylvania  University        1280                    40
# 40               U Va  University        1218                    36
# 41               UCLA  University        1142                    42
# 42                UNC  University        1109                    31
# 43             Vassar    Lib Arts        1287                    47
# 44  Washington U (MO)  University        1225                    53
# 45  Washinton and Lee    Lib Arts        1234                    33
# 46          Wellesley    Lib Arts        1250                    53
# 47      Wesleyan (CT)    Lib Arts        1290                    39
# 48           Williams    Lib Arts        1336                    32
# 49               Yale  University        1350                    18
#
#    Expenditures_per_Student  Graduation_perc
# 0                  $23,972                93
# 1                  $15,887                80
# 2                  $15,798                88
# 3                  $26,031                68
# 4                  $23,132                90
# 5                  $26,621                90
# 6                  $16,962                84
# 7                 $112,488                75
# 8                  $14,313                80
# 9                  $36,967                77
# 10                 $18,339                74
# 11                 $16,984                84
# 12                 $15,768                85
# 13                 $50,466                90
# 14                 $40,850                83
# 15                 $15,948                89
# 16                 $43,454                91
# 17                 $25,426                89
# 18                 $20,070                73
# 19                 $18,649                85
# 20                 $51,609                90
# 21                 $17,476                87
# 22                 $50,006                86
# 23                 $22,246                92
# 24                 $62,442                86
# 25                 $21,022                83
# 26                 $31,736                82
# 27                 $21,231                77
# 28                 $18,172                72
# 29                 $24,001                80
# 30                 $52,935                93
# 31                 $29,403                88
# 32                 $22,743                87
# 33                 $68,113                88
# 34                 $24,738                88
# 35                 $36,850                90
# 36                 $24,038                77
# 37                 $42,830                73
# 38                 $42,456                73
# 39                 $33,970                86
# 40                 $21,301                88
# 41                 $29,544                61
# 42                 $21,652                73
# 43                 $18,161                84
# 44                 $43,871                76
# 45                 $16,198                78
# 46                 $25,091                86
# 47                 $17,953                91
# 48                 $21,394                93
# 49                 $57,714                93

# %%
from bokeh.charts import Scatter, output_file, show

output_notebook()


p = Scatter(df, x='Acceptance_Rate_Perc', y='Median_SAT', title="Universities",
            xlabel="Acceptance Rate", ylabel="Media SAT")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f83a914c-0b6b-4ae4-adf8-30abb14f2220">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="47e6aa77-0ecc-4d23-aecf-816f1fcc7639"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("47e6aa77-0ecc-4d23-aecf-816f1fcc7639").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("47e6aa77-0ecc-4d23-aecf-816f1fcc7639");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '47e6aa77-0ecc-4d23-aecf-816f1fcc7639' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"580bb0e1-3798-4217-8a24-6fe538ed75c7":{"roots":{"references":[{"attributes":{},"id":"131835aa-3c99-4340-b62f-10a2d5b953eb","type":"ToolEvents"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"b5cb7936-9fca-4d25-a74a-a2bbe70e2563","type":"Range1d"},{"attributes":{"plot":null,"text":"Universities"},"id":"f6321ef5-bb86-4e67-b899-da18e104cee0","type":"Title"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"40901e63-975b-4077-90c8-789c07350ce4","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1846f56f-f484-478f-8527-a7dab206fb91","type":"PanTool"},{"id":"84f650a2-ce7f-4b0f-816f-f0abc10cdb8f","type":"WheelZoomTool"},{"id":"b74a1fa3-c179-4080-8923-626af4395d84","type":"BoxZoomTool"},{"id":"a07475d3-f4ff-4823-93fe-5936b3b1f9f1","type":"SaveTool"},{"id":"73dee04b-9f3a-4284-b83a-b95f7125d645","type":"ResetTool"},{"id":"34a8bb9e-feed-4a99-8d05-b06849c5a812","type":"HelpTool"}]},"id":"880fbf44-ef01-4368-a18e-a65931634b73","type":"Toolbar"},{"attributes":{"data_source":{"id":"a1c0e9b0-b749-4b1c-8285-cd0fed80fbb1","type":"ColumnDataSource"},"glyph":{"id":"40901e63-975b-4077-90c8-789c07350ce4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"90dc12ba-1556-4e16-91e4-351fa9d6bd18","type":"GlyphRenderer"},{"attributes":{"axis_label":"Acceptance Rate","formatter":{"id":"85c4845a-3b69-4450-b46d-06038220ff2d","type":"BasicTickFormatter"},"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"},"ticker":{"id":"193389e6-5683-469c-b114-80e8b16f06db","type":"BasicTicker"}},"id":"9e4d27ec-98ad-4bc5-afa0-5d70741fda67","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"66ea0d7f-f03c-4f38-90c0-5f488250ae46","type":"Legend"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"aff6a999-4e65-4ef0-b8af-81b6dc170e9e","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0eaa9fdc-db1b-4c94-905d-5657007fa830","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"1846f56f-f484-478f-8527-a7dab206fb91","type":"PanTool"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"84f650a2-ce7f-4b0f-816f-f0abc10cdb8f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"0eaa9fdc-db1b-4c94-905d-5657007fa830","type":"BoxAnnotation"},"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"b74a1fa3-c179-4080-8923-626af4395d84","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"a07475d3-f4ff-4823-93fe-5936b3b1f9f1","type":"SaveTool"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"73dee04b-9f3a-4284-b83a-b95f7125d645","type":"ResetTool"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"}},"id":"34a8bb9e-feed-4a99-8d05-b06849c5a812","type":"HelpTool"},{"attributes":{},"id":"85c4845a-3b69-4450-b46d-06038220ff2d","type":"BasicTickFormatter"},{"attributes":{},"id":"193389e6-5683-469c-b114-80e8b16f06db","type":"BasicTicker"},{"attributes":{"plot":{"id":"795c3f3d-11c0-4fcf-83a2-dcd4f4ae47e9","subtype":"Chart","type":"Plot"},"ticker":{"id":"193389e6-5683-469c-b114-80e8b16f06db","type":"BasicTicker"}},"id":"ecbbca2d-d3 ...

# %%
p = Scatter(df, x='Acceptance_Rate_Perc', y='Graduation_perc', title="Universities",
            xlabel="Acceptance Rate", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e5f98740-3881-4dea-a8dd-835b14d7dbb7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e5f98740-3881-4dea-a8dd-835b14d7dbb7").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e5f98740-3881-4dea-a8dd-835b14d7dbb7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e5f98740-3881-4dea-a8dd-835b14d7dbb7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6cc20d4a-e837-45c2-b094-63ebdb47c7f6":{"roots":{"references":[{"attributes":{"plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"}},"id":"a1757a37-649a-4cb4-9b30-f8c1eb51c9a7","type":"SaveTool"},{"attributes":{"plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"}},"id":"cd4e853b-3f8a-494e-bf54-b27dbe2b9fb3","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[26,57,40,36,28,23,60,30,44,63,40,50,42,28,29,40,24,23,71,42,17,39,47,29,29,65,46,58,53,37,16,23,61,17,28,19,59,44,55,40,36,42,31,47,53,33,53,39,32,18],"y_values":[93,80,88,68,90,90,84,75,80,77,74,84,85,90,83,89,91,89,73,85,90,87,86,92,86,83,82,77,72,80,93,88,87,88,88,90,77,73,73,86,88,61,73,84,76,78,86,91,93,93]}},"id":"02bf4148-cffd-4f49-b679-673dc4b6de36","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c8ab8419-21da-40fa-aad7-b0d29351ed68","type":"Circle"},{"attributes":{"callback":null,"end":96.2,"start":57.8},"id":"02e10b42-23b5-495f-8e4d-60b26c626c9c","type":"Range1d"},{"attributes":{},"id":"17b14139-c5de-41ee-9ad9-b881d916ca69","type":"ToolEvents"},{"attributes":{"axis_label":"Acceptance Rate","formatter":{"id":"076331b8-bee7-489a-b0d7-ec5ed16d1001","type":"BasicTickFormatter"},"plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"},"ticker":{"id":"936c1e8f-8da8-42c7-82e9-81187ba28df4","type":"BasicTicker"}},"id":"b4e9f2ff-93b8-45fc-8553-ff5c5c3faed6","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3f68053f-1e6c-4be2-8797-67ea20ab3bdc","type":"PanTool"},{"id":"4b0a1118-d967-4422-9946-2a083e91ee57","type":"WheelZoomTool"},{"id":"ab14a2ad-edc6-4759-9e5c-24a85aa77ed9","type":"BoxZoomTool"},{"id":"a1757a37-649a-4cb4-9b30-f8c1eb51c9a7","type":"SaveTool"},{"id":"cd49997b-b1b9-4bd6-8f71-7c00dd81d26c","type":"ResetTool"},{"id":"cd4e853b-3f8a-494e-bf54-b27dbe2b9fb3","type":"HelpTool"}]},"id":"8f7f2446-68d6-4226-b90d-e9c2e9849841","type":"Toolbar"},{"attributes":{"data_source":{"id":"02bf4148-cffd-4f49-b679-673dc4b6de36","type":"ColumnDataSource"},"glyph":{"id":"c8ab8419-21da-40fa-aad7-b0d29351ed68","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fcb0bee9-93ab-43f0-b2c5-ba8f3ad529b5","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"e97e2ba2-c15c-4a76-a0ee-9b9bf2e706b8","type":"Range1d"},{"attributes":{"plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"}},"id":"3f68053f-1e6c-4be2-8797-67ea20ab3bdc","type":"PanTool"},{"attributes":{"location":"top_left","plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"}},"id":"b1ed62f4-b071-4056-97db-46962c8976b0","type":"Legend"},{"attributes":{"plot":null,"text":"Universities"},"id":"37b39668-c848-4ffb-a5cb-41eb3c644555","type":"Title"},{"attributes":{"plot":{"id":"db550cec-59a2-465a-9b5d-70e0b2ebba11","subtype":"Chart","type":"Plot"}},"id":"4b0a1118-d967-4422-9946-2a083e91ee57","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a42b68fc-962c-46bb-9878-73597b9e7c18","type":"BoxAnnotation"},{"attributes":{},"id":"96a5ad1c-5371-4d ...

# %%
p = Scatter(df, x='Median_SAT', y='Graduation_perc', title="Universities",
            xlabel="Median_SAT", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c7ad2045-3ea5-481b-9241-ab6a84a9ba9d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c7ad2045-3ea5-481b-9241-ab6a84a9ba9d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c7ad2045-3ea5-481b-9241-ab6a84a9ba9d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c7ad2045-3ea5-481b-9241-ab6a84a9ba9d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c084c558-b97a-424d-be09-06d86a5402ca":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cda602f3-84f6-4add-81d4-bbe414735a16","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b3401657-b7ea-4b52-8dc9-1843c118a98b","subtype":"Chart","type":"Plot"}},"id":"322d04b0-2475-43cf-a586-03ce4baf3f8d","type":"ResetTool"},{"attributes":{"plot":{"id":"b3401657-b7ea-4b52-8dc9-1843c118a98b","subtype":"Chart","type":"Plot"}},"id":"1696c771-8906-432c-9db8-d4d0db265eb2","type":"HelpTool"},{"attributes":{"plot":{"id":"b3401657-b7ea-4b52-8dc9-1843c118a98b","subtype":"Chart","type":"Plot"}},"id":"b750d5ad-8df2-408b-9369-b782904a4825","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Universities"},"id":"151bab84-fd4b-4eaf-bf72-53cbc5d30839","type":"Title"},{"attributes":{"axis_label":"Graduation_perc","formatter":{"id":"fc240694-45b1-498a-be6b-926f69801e3c","type":"BasicTickFormatter"},"plot":{"id":"b3401657-b7ea-4b52-8dc9-1843c118a98b","subtype":"Chart","type":"Plot"},"ticker":{"id":"43f5dfbd-f4b8-4111-b169-4bc3288ce525","type":"BasicTicker"}},"id":"460c9000-72b0-4dc8-af88-166f6bb2aa30","type":"LinearAxis"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"73037c43-b40e-4e00-8e04-abef61f25458","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d23f9dbc-b4d0-4f41-adb5-b65bd8f154bc","type":"PanTool"},{"id":"b750d5ad-8df2-408b-9369-b782904a4825","type":"WheelZoomTool"},{"id":"ca5f5b4d-4ba1-4c81-886d-50cc03c3f93c","type":"BoxZoomTool"},{"id":"fb0e978d-9fa2-465c-b7b8-ac57e97cfcb8","type":"SaveTool"},{"id":"322d04b0-2475-43cf-a586-03ce4baf3f8d","type":"ResetTool"},{"id":"1696c771-8906-432c-9db8-d4d0db265eb2","type":"HelpTool"}]},"id":"8886d7a0-fb73-45b6-83ea-dbdbd2fe2cb7","type":"Toolbar"},{"attributes":{"below":[{"id":"8dbf19a9-291e-4d74-8789-4b9dc113bb0a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"460c9000-72b0-4dc8-af88-166f6bb2aa30","type":"LinearAxis"}],"renderers":[{"id":"cda602f3-84f6-4add-81d4-bbe414735a16","type":"BoxAnnotation"},{"id":"aa471c0b-70d1-4d3f-b111-51e607a1d749","type":"GlyphRenderer"},{"id":"dfa627cf-bea2-4fe3-bbaf-9b9487a938f0","type":"Legend"},{"id":"8dbf19a9-291e-4d74-8789-4b9dc113bb0a","type":"LinearAxis"},{"id":"460c9000-72b0-4dc8-af88-166f6bb2aa30","type":"LinearAxis"},{"id":"6a786031-25de-4670-b1a4-cbdf2ca3a73b","type":"Grid"},{"id":"302cacff-b87e-4be9-8f7e-c9ac05b6e0d5","type":"Grid"}],"title":{"id":"151bab84-fd4b-4eaf-bf72-53cbc5d30839","type":"Title"},"tool_events":{"id":"4d85fd44-63d9-47bb-a531-f54c0fae22ac","type":"ToolEvents"},"toolbar":{"id":"8886d7a0-fb73-45b6-83ea-dbdbd2fe2cb7","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"73037c43-b40e-4e00-8e04-abef61f25458","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"a0a70b3e-c8c3-465b-b760-e26241cd9c16","type":"Range1d"}},"id":"b3401657-b7ea-4b52-8dc9-1843c118a98b","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[1315,1220,1240,1176,1300,1281,1255,1400,1300,1225,1260,1200,1258,1268,1280,1230,1310,1278,1244,1215,1370,1285,1290,1255,1357,1200,1230,1247,1170,1320,1340,1327,1195,1370,1310,1350,1195,1300,1155,1280,1218,1142,1109,1287,1225,1234,1250,1290,1336,1350],"y_values":[93,80,88,68,90,90,84,75,80,77,74,84,85,90,83,89,91,89,73,85,90,87,86,92,86,83,82,77,72,80,93,88,87,88,88,90,77,73,73,86,88,61, ...
